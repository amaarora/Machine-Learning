# %% [markdown]
# **About the data:** In accordance with section 22D of the Public Sector Management Act 1994, the Public Sector Commissioner reports annually to Parliament on the state of public sector administration and management, and on the extent of compliance with public sector standards and ethical codes. One of the primary information sources used for the State of the WA public sector report 2015 - Creating opportunities is the employee perception survey (EPS). <br>
# The EPS captures employee views about factors affecting their workplace, such as leadership, communication, work/life balance and performance development. This information helps to understand organisational culture across the public sector and is essential in identifying areas for further consideration and acknowledging good practice. <br>
# The EPS is typically conducted in each public sector body with more than 20 employees once every five years. Different regional offices for the largest agencies, Department of Health and Department of Education, are surveyed every year.
#
# For more information on the data set, please refer to https://data.gov.au/dataset/public-sector-commission-wa-employee-perception-survey-2015. <br>
#
# The PDF version of the actual survey form can be found at https://data.gov.au/dataset/public-sector-commission-wa-employee-perception-survey-2015/resource/f6b6fb5f-0370-4524-a159-9a31840e1e5a/proxy

# %% [markdown]
# References: <br>
# - https://www.dataquest.io/blog/machine-learning-preparing-data/
# - Plotly code was resued from https://www.kaggle.com/arthurtok/interactive-porto-insights-a-plot-ly-tutorial
# - Graphviz visualisation code was resued from `decision_trees` notebook `General Assembly, Sydney` taught by Dima Galat. (https://www.linkedin.com/in/dimagalat/)

# %%
#libraries
import pandas as pd 
import seaborn as sns 
from matplotlib import pyplot as plt 
import numpy as np

#config
pd.set_option('display.max_colwidth', 5000)

# pd.set_option("display.max_rows",120)
pd.set_option("display.max_columns",120)

# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import warnings
import graphviz 
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier, \
                             AdaBoostClassifier, VotingClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import graphviz 
from sklearn.metrics import accuracy_score,confusion_matrix, roc_curve
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import average_precision_score,f1_score,cohen_kappa_score
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier
from sklearn.linear_model import LogisticRegression, LinearRegression
import mglearn
import warnings
warnings.filterwarnings("ignore")
from sklearn.svm import LinearSVC, SVC
from sklearn.model_selection import cross_val_score
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
#import data
data_path = '/Users/user/Desktop/Folders/Data_Scientist/data/public-sector-commission-eps-2015-data.xlsx'

#read files
survey = pd.read_excel(data_path, na_values = 8,sheet_name = 'Data')

survey_question = pd.read_excel(data_path, na_values = 8, 
                                sheet_name = 'Question key')

survey_answer_values = pd.read_excel(data_path, sheet_name = 'Response key')

#create dictionary
survey_dict = dict(zip(survey_question['Question ID'], survey_question['Question ']))

# %%
#drop columns with >50% null values
print("Number of columns in our dataframe: {:d}".format(survey.shape[1]))
half_count = len(survey) / 2
survey = survey.dropna(thresh=half_count,axis=1)
print("Number of columns left in our dataframe after drop: {:d}". \
      format(survey.shape[1]))
# Out:
# Number of columns in our dataframe: 110
# Number of columns left in our dataframe after drop: 80

# %% [markdown]
# **Exploratory Data Analysis**

# %%
#survey questions description
survey_question.rename(columns = {'Question ID' : 'question_id',
                                  'Question ': 'description'}, inplace = True)

#new dataframe for eda
survey_dtypes = pd.DataFrame(survey.dtypes,columns=['dtypes'])
survey_dtypes.reset_index(inplace = True)
survey_dtypes.rename(columns = {'index' : 'question_id'},inplace = True)
survey_dtypes['unique_values'] = list(survey.nunique())

#get first row values from main df
survey_dtypes['first_row_value'] = survey.loc[0].values

#new col - 'category' based on employee survey form 
survey_dtypes['question_category'] = 'null'
survey_dtypes.loc[0:2,'question_category']   = 'overall_job_satisfaction'
survey_dtypes.loc[2:9,'question_category']   = 'current_job_related'
survey_dtypes.loc[10:23,'question_category'] = 'agency_related'
survey_dtypes.loc[24:25,'question_category'] = 'workplace_communication'
survey_dtypes.loc[26:29,'question_category'] = 'immediate_supervisor'
survey_dtypes.loc[30:33,'question_category'] = 'immediate_work_group'
survey_dtypes.loc[34:37,'question_category'] = 'performance_development'
survey_dtypes.loc[38:41,'question_category'] = 'equity_and_diversity'
survey_dtypes.loc[42:45,'question_category'] = 'misc'
survey_dtypes.loc[46:52,'question_category'] = 'ethical_behaviour'
survey_dtypes.loc[53:54,'question_category'] = 'misc'
survey_dtypes.loc[55:69,'question_category'] = 'ethical_behaviour_at_workplace'
survey_dtypes.loc[70:74,'question_category'] = 'misc'
survey_dtypes.loc[75:78,'question_category'] = 'further_information'
survey_dtypes.loc[79:,'question_category'] = 'agency_size'

# %%
#create copy called 'preview' for eda
preview = survey_dtypes.merge(survey_question, on = 'question_id', how = 'left')

# %% [markdown]
# As we saw in our `survey` shape, it had 80 columns, therefore, preview will have 80 rows. So, we will break it down to 4 parts of 20 rows each.

# %% [markdown]
# As you explore the features to better understand each of them, you'll want to pay attention to any column that:
#
# - leaks information from the future
# - is formatted poorly,<br>
# - requires more data or a lot of preprocessing to turn into useful a feature, or
# - contains redundant information.

# %% [markdown]
# **First group of columns:**

# %%
#Preview first 20 rows
preview[:21]
# Out:
#                          question_id   dtypes  unique_values  first_row_value  \
# 0           overall_job_satisfaction  float64              7              1.0
# 1        overall_agency_satisfaction  float64              7              2.0
# 2       job_allows_to_utilise_skills  float64              7              1.0
# 3     clarity_about_responsibilities  float64              7              2.0
# 4      understand_works_contribution  float64              7              1.0
# 5                authority_to_do_job  float64              7              2.0
# 6    sufficiently_challenged_by_work  float64              7              2.0
# 7                        recognition  float64              7              2.0
# 8   career_progression_opportunities  float64              7              2.0
# 9               proud_to_work_in_WPS  float64              7              1.0
# 10            agency_is_well_managed  float64              7              2.0
# 11                 change_management  float64              7              2.0
# 12             agency_senior_leaders  float64              7              2.0
# 13         technological_utilisation  float64              7              2.0
# 14       fair_recruitement_decisions  float64              7              2.0
# 15                 work_life_balance  float64              7              3.0
# 16        flexible_work_arrangements  float64              7              3.0
# 17              health_and_wellbeing  float64              7              1.0
# 18               personal_attachment  float64              7              2.0
# 19              motivates_me_to_work  float64              7              2.0
# 20           inspires_to_do_best_job  float64              7              2.0
#
#            question_category  \
# 0   overall_job_satisfaction
# 1   overall_job_satisfaction
# 2        current_job_related
# 3        current_job_related
# 4        current_job_related
# 5        current_job_related
# 6        current_job_related
# 7        current_job_related
# 8        current_job_related
# 9        current_job_related
# 10            agency_related
# 11            agency_related
# 12            agency_related
# 13            agency_related
# 14            agency_related
# 15            agency_related
# 16            agency_related
# 17            agency_related
# 18            agency_related
# 19            agency_related
# 20            agency_related
#
#                                                                                                           description
# 0                                                     Please indicate your level of satisfaction with: My job overall
# 1                                           Please indicate your level of satisfaction with: My agency as an employer
# 2                                                      My job allows me to utilise my skills, knowledge and abilities
# 3                                                                  I am clear what my duties and responsibilities are
# 4                                                      I understand how my work contributes to my agency’s objectives
# 5   I have the authority (e.g. the necessary delegations, autonomy, level of responsibility) to do my job effectively
# 6                                                                             I am sufficiently challenged by my work
# 7                                                                         I am recognised for the contribution I make
# 8                   I am satisfied with the opportunities available to me for career progression in my current agency
# 9                                                          I am proud to work in the Western Australian public sector
# 10                                                                 I feel that my agency on the whole is well managed
# 11                                                                                Change is managed well in my agency
# 12                                                            My agency’s senior leaders provide effective leadership
# 13                 My agency uses  technological advances to improve service design and delivery to customers/clients
# 14                                                          Recruitment and promotion decisions in my agency are fair
# 15                                       My workplace culture supports people to achieve a suitable work/life balance
# 16                     You are able to access and use flexible work arrangements  to assist in your work/life balance
# 17                                                My agency is committed to health and wellbeing within the workplace
# 18                                                                   I feel a strong personal attachment to my agency
# 19                                                           My agency motivates me to help it achieve its objectives
# 20                                                                     My agency inspires me to do the best in my job

# %% [markdown]
# Our **target** variable is **overall_job_satisfaction**. As part of this project, **we will NOT be predicting** overall satisfaction with the agency - 'overall_agency_satisfaction'.
#
# Questions from `10` to `16` are related to the overall satisfaction with the Agency and not Job Satisfaction in itself, therefore, we will be dropping these columns as they are unrelated to what we want to predict. We will be dropping these columns as a whole OR we could feature engineer to keep the 'median'.

# %%
#rename target
survey.rename({'overall_job_satisfaction':'target'},inplace = True, axis = 1)

#drop columns
drop_list = np.array(survey_dtypes.loc[11:20,'question_id'])
survey.drop(drop_list,axis=1,inplace = True)
survey.drop('overall_agency_satisfaction',axis=1, inplace = True)

# %% [markdown]
# **Second group of columns:**

# %%
#preview next 20 rows
preview[21:41]
# Out:
#                                     question_id   dtypes  unique_values  \
# 21                           proud_to_work_here  float64              7
# 22                recommend_others_to_work_here  float64              7
# 23                              likely_to_leave  float64              3
# 24                      effective_communication  float64              7
# 25                               input_is_heard  float64              7
# 26        manager_has_good_interpersonal_skills  float64              7
# 27                  business_risk_communication  float64              7
# 28                      supervisor_manages_well  float64              7
# 29         poor_employee_performance_dealt_with  float64              7
# 30  effective_utilisation_of_time_and_resources  float64              7
# 31                   high_level_of_productivity  float64              7
# 32                          innovative_approach  float64              7
# 33                   excellent_customer_service  float64              7
# 34        training_and_development_to_employees  float64              7
# 35                 receive_appropriate_training  float64              7
# 36                   receive_perfmance_feedback  float64              7
# 37          adequate_opportunity_to_be_a_leader  float64              7
# 38                            diverse_workforce  float64              7
# 39                             welcoming_nature  float64              7
# 40                         equal_respect_to_all  float64              7
#
#     first_row_value        question_category  \
# 21              1.0           agency_related
# 22              1.0           agency_related
# 23              3.0           agency_related
# 24              2.0  workplace_communication
# 25              2.0  workplace_communication
# 26              2.0     immediate_supervisor
# 27              2.0     immediate_supervisor
# 28              2.0     immediate_supervisor
# 29              2.0     immediate_supervisor
# 30              1.0     immediate_work_group
# 31              1.0     immediate_work_group
# 32              2.0     immediate_work_group
# 33              1.0     immediate_work_group
# 34              4.0  performance_development
# 35              3.0  performance_development
# 36              1.0  performance_development
# 37              2.0  performance_development
# 38              2.0     equity_and_diversity
# 39              2.0     equity_and_diversity
# 40              1.0     equity_and_diversity
#
#                                                                                                                             description
# 21                                                                                       I am proud to tell others I work for my agency
# 22                                                                                 I would recommend my agency as a great place to work
# 23                                                                                 It is likely that you will leave your agency within:
# 24                                              In my work area, communication between senior managers and other employees is effective
# 25                                                 My input is adequately sought and considered about decisions that directly affect me
# 26                         My immediate supervisor makes use of appropriate communication and interpersonal skills when dealing with me
# 27                                My immediate supervisor effectively communicates with me about business risks impacting my work group
# 28                                                                              My immediate supervisor is effective in managing people
# 29                                                        My immediate supervisor appropriately deals with employees who perform poorly
# 30                                                                 The people in my work group use their time and resources efficiently
# 31                                                                                  My work group achieves a high level of productivity
# 32                                                In the last 12 months, my work group has implemented innovative processes or policies
# 33  The people in my work group are committed to providing excellent customer service and making a positive difference to the community
# 34                                                Training and development opportunities in my work area are available to all employees
# 35               I receive appropriate training or have access to information that enables me to meet my recordkeeping responsibilities
# 36                         I have received performance feedback from my supervisor in the last 12 months that has helped my performance
# 37                                        In my agency, there is adequate opportunity to develop the required skills for being a leader
# 38                                                                             Your agency is committed to creating a diverse workforce
# 39                                                      Your workplace culture is equally welcoming of people from all diversity groups
# 40                                              Your immediate supervisor treats employees from all diversity groups with equal respect

# %% [markdown]
# We will be dropping `agency_related` columns `21-23`. <br>
# We will be keeping all the other columns.

# %%
#drop columns
drop_list = np.array(survey_dtypes.loc[21:23,'question_id'])
survey.drop(drop_list, axis=1, inplace = True)

# %% [markdown]
# **Third group of columns:**

# %%
#preview next 20 rows
preview[41:61]
# Out:
#                                          question_id   dtypes  unique_values  \
# 41                  different_diversity_treated_well  float64              7
# 42                                                B6  float64              3
# 43                                                B8  float64              3
# 44                                              B8ai  float64              1
# 45                       performance_and_development  float64              6
# 46                      encourages_ethical_behaviour  float64              7
# 47                  senior_manager_ethics_are_strong  float64              7
# 48                            conflicts_managed_well  float64              7
# 49                  supervisor_honesty_and_integrity  float64              7
# 50                   coworkers_honesty_and_integrity  float64              7
# 51             confidential_information_managed_well  float64              7
# 52  purchasing_decisions_not_influenced_by_incentive  float64              7
# 53                                                C2  float64              2
# 54                                                C3  float64              2
# 55                  witnessed_unprofessional_conduct  float64              5
# 56                        failure_to_manage_conflict  float64              5
# 57                                provision_of_gifts  float64              5
# 58                                 corrupt_behaviour  float64              5
# 59                          improper_use_of_computer  float64              5
# 60                                       harrassment  float64              5
#
#     first_row_value               question_category  \
# 41              1.0            equity_and_diversity
# 42              2.0                            misc
# 43              1.0                            misc
# 44              1.0                            misc
# 45              1.0                            misc
# 46              1.0               ethical_behaviour
# 47              1.0               ethical_behaviour
# 48              2.0               ethical_behaviour
# 49              1.0               ethical_behaviour
# 50              1.0               ethical_behaviour
# 51              1.0               ethical_behaviour
# 52              1.0               ethical_behaviour
# 53              1.0                            misc
# 54              1.0                            misc
# 55              1.0  ethical_behaviour_at_workplace
# 56              1.0  ethical_behaviour_at_workplace
# 57              1.0  ethical_behaviour_at_workplace
# 58              1.0  ethical_behaviour_at_workplace
# 59              1.0  ethical_behaviour_at_workplace
# 60              1.0  ethical_behaviour_at_workplace
#
#                                                                                                                                                                                                                                                 description
# 41                                                                                                                                                                             Your co-workers treat employees from all diversity groups with equal respect
# 42                                                                                                                                                                               Are you aware of the Public Sector Standards in Human Resource Management?
# 43                                          If you have been employed in your agency for more than 12 months, have you participated in one or more formal, documented performance management meetings with your immediate supervisor in the past 12 months?
# 44                                                                                                                  If yes, which of the following topics were discussed within these formal, documented, meetings?: My work performance over the last year
# 45                                                                                                       How often do you meet with your immediate supervisor informally in a setting that allows for discussion about performance and development matters?
# 46                                                                                                                                                                                  My agency actively encourages ethical behaviour by all of its employees
# 47                                                                                                                                                                                        Senior managers in my agency lead by example in ethical behaviour
# 48                                                                                                                                                                             Conflicts of interest are identified and managed effectively in my workplace
# 49                                                                                                                                                                              My immediate supervisor demonstrates honesty and integrity in the workplace
# 50                                                                                                                                                                                         My co-workers demonstrate honesty and integrity in the workplace
# 51                                                                                                                                                                         Confidential information in my workplace is only disclosed to appropriate people
# 52                                                                                                                                                                          Purchasing decisions in my  workplace are not influenced by gifts or incentives
# 53                                                                                                                                                                                                  Are you familiar with the Public Sector Code of Ethics?
# 54                                                                                                                                                                                                       Are you familiar with your agency code of conduct?
# 55                                                       Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Unprofessional conduct (e.g. bullying, inappropriate language)
# 56                   Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Failure to manage conflicts of interest (e.g. conflict between public role and personal interests)
# 57                                                           Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Inappropriate acceptance or provision of gifts or benefits
# 58     Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Corrupt behaviour (e.g. employees misusing their position to obtain an inappropriate benefit or cause detriment)
# 59  Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Improper use of work computers, internet or email (e.g. viewing or sharing inappropriate or illegal online content)
# 60                                         Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Discrimination or harassment (e.g. racial discrimination, sexual harassment)

# %% [markdown]
# We will be dropping the `misc` category questions and will be keeping questions related to `ethical_behaviour`. <br>
# Questions related to `ethical_behaviour_at_workplace` are dummy variables. We shall be keeping the round median() value to not lose a lot of information and yet, significiantly reduce the number of columns.

# %%
#drop columns
drop_list = np.array(survey_dtypes.loc[42:45,'question_id'])
drop_list = np.append(drop_list, np.array(survey_dtypes.loc[53:54,'question_id']))
survey.drop(drop_list, axis=1, inplace = True)

# %%
#capture aggregate information
survey['ethical_behaviour_med'] = survey.iloc[:,55:60].median(axis = 1)

#drop individual cols
drop_list = np.array(survey_dtypes.loc[55:60,'question_id'])
survey.drop(drop_list, axis=1, inplace = True)

# %% [markdown]
# **Fourth group of columns:**

# %%
#preview last 20 rows
preview[61:]
# Out:
#                           question_id   dtypes  unique_values  \
# 61                           drug_use  float64              5
# 62                            assault  float64              5
# 63   confidential_information_leakage  float64              5
# 64                    bribes_or_theft  float64              5
# 65         misuse_of_public_resources  float64              5
# 66                fradulent_behaviour  float64              5
# 67                    neglect_of_duty  float64              5
# 68                 criminal_behaviour  float64              5
# 69                    having_two_jobs  float64              5
# 70                               C4ii  float64              4
# 71                                 C5  float64              2
# 72                                 C6  float64              3
# 73                                 C7  float64              2
# 74                                 C8  float64              3
# 75                             gender  float64              2
# 76         highest_level_of_education  float64              2
# 77                       total_salary  float64              5
# 78  employed_in_top_four_managemement  float64              2
# 79                        agency_size    int64              3
#
#     first_row_value               question_category  \
# 61              1.0  ethical_behaviour_at_workplace
# 62              1.0  ethical_behaviour_at_workplace
# 63              1.0  ethical_behaviour_at_workplace
# 64              1.0  ethical_behaviour_at_workplace
# 65              1.0  ethical_behaviour_at_workplace
# 66              1.0  ethical_behaviour_at_workplace
# 67              1.0  ethical_behaviour_at_workplace
# 68              1.0  ethical_behaviour_at_workplace
# 69              1.0  ethical_behaviour_at_workplace
# 70              NaN                            misc
# 71              NaN                            misc
# 72              2.0                            misc
# 73              1.0                            misc
# 74              3.0                            misc
# 75              1.0             further_information
# 76              2.0             further_information
# 77              3.0             further_information
# 78              2.0             further_information
# 79              3.0                     agency_size
#
#                                                                                                                                                                                                                                  description
# 61                                                          Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Illicit drug use and/or alcohol intoxication
# 62                                   Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Inappropriate physical behaviour (e.g. assault, indecent behaviour)
# 63  Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Inappropriate access to or use of confidential information or unauthorised disclosure of information
# 64                               Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Workplace bribes or theft (e.g. computers, cash or workplace equipment)
# 65       Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Misuse of public resources (e.g. unauthorised use of vehicles, misuse of corporate credit card)
# 66                                       Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Fraudulent behaviour or falsification of information or records
# 67                                   Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Neglect of duty (e.g. intentionally failing to perform work duties)
# 68                                                           Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Engaging in criminal behaviour outside work
# 69                             Have you witnessed any of the following types of unethical behaviour in your workplace in the last 12 months, and if so how often?: Secretly holding another job outside government without agency permission
# 70                                                                                                                                                           If you have witnessed unethical behaviour in your workplace, did you report it?
# 71                                                                                                                                                                           Do you know how to report unethical behavior in your workplace?
# 72                                                                                                                                                During the past 12 months, have you been subjected to repeated bullying in your workplace?
# 73                                                                                                                                                                                     Do you know how to report bullying in your workplace?
# 74                                                                                                                                                                                Are you aware of the PID Act and how to make a disclosure?
# 75                                                                                                                                                                                                                      What is your gender?
# 76                                                                                                                                                                         What is the highest level of formal education you have completed?
# 77                                                                                                                                                                              What is your current total annual gross salary (before tax)?
# 78                                                               Are you employed in one of the top four levels of management in your agency’s organisational hierarchy (e.g. General Manager, Executive Director, Chief Executive Officer)?
# 79                                                                                                                                                                                                                Size of agency (headcount)

# %% [markdown]
# We will be keeping the `further_information` category and dropping the `misc` and `agency_size` columns.

# %%
#drop columns 
drop_list = drop_list = np.array(survey_dtypes.loc[61:74,'question_id'])
survey.drop(drop_list, axis=1, inplace = True)
survey.drop('agency_size', axis=1, inplace = True)

# %%
survey.shape
# Out:
# (11405, 40)

# %% [markdown]
# We have significiantly reduced our number of columns from 110 to 40.

# %%
# Function to calculate missing values by column# Funct 
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns
    
#Function call 
missing_values_table(survey).head()
# Out:
# Your selected dataframe has 40 columns.
# There are 39 columns that have missing values.
#                                                   Missing Values  \
# purchasing_decisions_not_influenced_by_incentive            1354
# poor_employee_performance_dealt_with                        1132
# conflicts_managed_well                                       907
# innovative_approach                                          789
# adequate_opportunity_to_be_a_leader                          525
#
#                                                   % of Total Values
# purchasing_decisions_not_influenced_by_incentive               11.9
# poor_employee_performance_dealt_with                            9.9
# conflicts_managed_well                                          8.0
# innovative_approach                                             6.9
# adequate_opportunity_to_be_a_leader                             4.6

# %%
#fillna with mode
survey = survey.apply(lambda x:x.fillna(x.value_counts().index[0]))

# %%
corr = survey.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
fig, ax = plt.subplots(figsize=(15, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
a = sns.heatmap(corr, mask=mask, cmap=cmap, center = 0.2, 
            vmax=1, ax = ax, square = True,
            linewidths=.5, cbar_kws={"shrink":0.5} );

# %% [markdown]
# Most features are correlated to each other. Let's find out which are the features that are the most correlated to our target variable.

# %%
correlations_neg =  survey.corr()['target'].sort_values()
correlations_pos = survey.corr()['target'].sort_values(ascending = False)

#positive correlation
fig,ax = plt.subplots(figsize = (15,8))
df = pd.DataFrame(correlations_pos.head(30))[1:]
# df.plot(kind = 'barh', ax = ax, color = 'lightsalmon');
# plt.title('Factors that have high correlation with Job Satisfaction');
# ax.grid()
a = sns.barplot(x='target',y='index', data = df.reset_index(), color = 'lightsalmon', orient = 'h');
ax.set_xlabel('Correlation Value');
ax.set_ylabel('Features');
ax.grid(axis = 'x')

# %% [markdown]
# It seems like 'My job allows me to utilise my skills, knowledge and abilitie' plays the most important role in Job Satisfaction.

# %%
#for meaningful plots
response_key = {
    1:'Very satisfied',
    2: 'Moderately satisfied',
    3: 'Mildly satisfied',
    4: 'Neither satisfied nor dissatisfied',
    5:'Mildly dissatisfied',
    6:'Moderately dissatisfied',
    7:'Very dissatisfied'
                }

# %%
#plot target variable
survey['target_plot'] = survey['target'].map(response_key)

fig,ax = plt.subplots(figsize = (10,6))

a = sns.countplot(x = 'target_plot', data = survey, 
                  color = 'salmon', 
                  order = ['Very satisfied','Moderately satisfied','Mildly satisfied',
                           'Neither satisfied nor dissatisfied','Mildly dissatisfied',
                           'Moderately dissatisfied','Very dissatisfied']);

ax.set(xlabel = 'Employee Satisfaction Distrbution');
ax.set(ylabel = 'Count');
ax.grid(which = 'major', axis = 'y')

#change xtick rotation
for item in a.get_xticklabels():
    item.set_rotation(-90)

# %%
#define feature_cols,X,y
feature_cols = survey.drop(['target','target_plot'],axis=1).columns
X = survey[feature_cols]
y = survey.target

# %%
#feature importance using RF
rf = RandomForestClassifier()

rf.fit(X, y)
features = X.columns.values

# %%
feature_imp = [x for x in zip(features,rf.feature_importances_)]
df = pd.DataFrame(feature_imp)
df.columns = ['features','feature_importance']
df.sort_values(by = 'feature_importance', ascending = False, inplace = True)

fig,ax = plt.subplots(figsize = (12,10))
sns.barplot(x = 'feature_importance' , y ='features', data = df, 
            orient= 'h', color = 'lightsalmon');
ax.grid(axis = 'x')

# %%
#redefine feature_cols,X,y - values were updated during plotting before
feature_cols = survey.drop(['target','target_plot'],axis=1).columns
X = survey[feature_cols]
y = survey.target

# %%
# Fitting a tree with max depth 3
treeclf = DecisionTreeClassifier(max_depth = 3, random_state=1)
treeclf.fit(X, y)

dot_data = export_graphviz(treeclf, out_file=None, feature_names=feature_cols)

graph = graphviz.Source(dot_data)  
graph

# %%
def generate_report(clf):
    """Return y_pred. 
    Takes input as a classifier, fits the classifier to the X_train,y_train data, predicts X_test and 
    generates classification reports for predicting X_test. Also calculates average accuracy, f1_scores and 
    displays confusion matrix."""
    
    
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    
    #classification report
    print("Classification Report:\n{}".format(classification_report(y_test,y_pred)))
    
    #accuracy and confusion matrix
    print("Accuracy: {:.3f}".format(accuracy_score(y_test, y_pred))) 
    print("\nConfusion matrix:\n{}".format(confusion_matrix(y_test, y_pred)))
    
    #micro,macro and weighted scores
    print("\nMicro average f1 score: {:.3f}".format (f1_score(y_test, y_pred, average="micro")))
    print("Macro average f1 score: {:.3f}".format (f1_score(y_test, y_pred, average="macro")))
    print("Weighted average f1 score: {:.3f}".format (f1_score(y_test, y_pred, average="weighted")))
    
    return y_pred

# %% [markdown]
# ## Model Fitting

# %% [markdown]
# **Train Test Split**

# %%
#test train split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2, random_state = 123)

# %% [markdown]
# **Linear SVC**

# %%
svc = LinearSVC()
svc_train = generate_report(LinearSVC())
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.64      0.75      0.69       730
#          2.0       0.50      0.66      0.57       927
#          3.0       0.00      0.00      0.00       310
#          4.0       0.00      0.00      0.00        77
#          5.0       0.00      0.00      0.00       100
#          6.0       0.20      0.02      0.04        90
#          7.0       0.15      0.64      0.24        47
#
#    micro avg       0.52      0.52      0.52      2281
#    macro avg       0.21      0.30      0.22      2281
# weighted avg       0.42      0.52      0.46      2281
#
# Accuracy: 0.523
#
# Confusion matrix:
# [[548 174   0   0   0   1   7]
#  [285 614   0   0   0   1  27]
#  [ 12 258   0   0   0   3  37]
#  [  1  55   0   0   0   0  21]
#  [  1  59   0   0   0   1  39]
#  [  2  45   0   0   0   2  41]
#  [  2  13   0   0   0   2  30]]
#
# Micro average f1 score: 0.523
# Macro average f1 score: 0.221
# Weighted average f1 score: 0.461

# %% [markdown]
# **Logistic Regression**

# %%
logreg = LogisticRegression()
logreg_train = generate_report(LogisticRegression())
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.65      0.72      0.68       730
#          2.0       0.50      0.71      0.58       927
#          3.0       0.20      0.07      0.11       310
#          4.0       0.00      0.00      0.00        77
#          5.0       0.08      0.01      0.02       100
#          6.0       0.17      0.07      0.10        90
#          7.0       0.71      0.11      0.19        47
#
#    micro avg       0.53      0.53      0.53      2281
#    macro avg       0.33      0.24      0.24      2281
# weighted avg       0.46      0.53      0.48      2281
#
# Accuracy: 0.532
#
# Confusion matrix:
# [[525 200   2   0   2   1   0]
#  [258 654  10   0   1   3   1]
#  [ 14 267  22   0   1   6   0]
#  [  1  62  13   0   0   1   0]
#  [  1  69  22   1   1   5   1]
#  [  2  47  28   1   6   6   0]
#  [  2  12  12   0   2  14   5]]
#
# Micro average f1 score: 0.532
# Macro average f1 score: 0.239
# Weighted average f1 score: 0.479

# %% [markdown]
# **GradientBoostingClassifier**

# %%
gbc = GradientBoostingClassifier()
gbc_train = generate_report(GradientBoostingClassifier(learning_rate=0.3))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.68      0.69      0.68       730
#          2.0       0.56      0.67      0.61       927
#          3.0       0.37      0.25      0.30       310
#          4.0       0.26      0.10      0.15        77
#          5.0       0.21      0.15      0.18       100
#          6.0       0.31      0.29      0.30        90
#          7.0       0.40      0.30      0.34        47
#
#    micro avg       0.55      0.55      0.55      2281
#    macro avg       0.40      0.35      0.36      2281
# weighted avg       0.53      0.55      0.54      2281
#
# Accuracy: 0.554
#
# Confusion matrix:
# [[505 211   7   1   1   0   5]
#  [220 619  61   2  12  10   3]
#  [  9 182  77   6  19  14   3]
#  [  2  29  25   8   8   5   0]
#  [  1  38  18  10  15  14   4]
#  [  6  20  16   4  12  26   6]
#  [  4   6   5   0   3  15  14]]
#
# Micro average f1 score: 0.554
# Macro average f1 score: 0.365
# Weighted average f1 score: 0.538

# %% [markdown]
# **AdaBoost**

# %%
ada = AdaBoostClassifier()
ada_train = generate_report(AdaBoostClassifier())
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.64      0.77      0.70       730
#          2.0       0.55      0.61      0.58       927
#          3.0       0.34      0.18      0.24       310
#          4.0       0.20      0.09      0.13        77
#          5.0       0.24      0.05      0.08       100
#          6.0       0.25      0.31      0.28        90
#          7.0       0.41      0.32      0.36        47
#
#    micro avg       0.54      0.54      0.54      2281
#    macro avg       0.37      0.33      0.34      2281
# weighted avg       0.51      0.54      0.52      2281
#
# Accuracy: 0.545
#
# Confusion matrix:
# [[562 162   2   0   1   2   1]
#  [282 569  54   4   4  11   3]
#  [ 12 200  57   7   6  24   4]
#  [  4  34  18   7   3  11   0]
#  [  2  37  21   9   5  19   7]
#  [  7  22  17   7   2  28   7]
#  [  4   8   1   1   0  18  15]]
#
# Micro average f1 score: 0.545
# Macro average f1 score: 0.337
# Weighted average f1 score: 0.519

# %% [markdown]
# **Ensemble using Voting Classifier**

# %%
estimators = []
model1 = logreg
estimators.append(('logistic', model1))
model2 = gbc
estimators.append(('gradient boosting classifier', model2))
model3 = svc
estimators.append(('svm', model3))
model4 = ada
estimators.append(('ada', model3))
# create the ensemble model
ensemble_clf = VotingClassifier(estimators=estimators,voting = 'hard')
results = cross_val_score(ensemble_clf, X, y, cv=3, scoring= 'accuracy', verbose = 1)
print(results.mean())
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 0.5413516992519599
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  1.1min finished

# %% [markdown]
# **Model Stacking**

# %%
X = survey[feature_cols]
y = survey.target
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.1, random_state = 60, stratify = y)

#create validation set for stacking
X_train,X_val,y_train,y_val = train_test_split(X_train,y_train,test_size = 0.1,  
                                                       random_state = 60, stratify = y_train)

# %%
model1 = logreg
model2 = gbc
model3 = svc
model4 = ada

#stack layer model
meta_model = LogisticRegression()

#fit models
print("Fiting Logistic Regression..")
model1.fit(X_train,y_train)
pred1 = model1.predict(X_test)
val1 = model1.predict(X_val)
print("Done")

print("Fiting GradientBoostedClassifier..")
model2.fit(X_train,y_train)
pred2 = model2.predict(X_test)
val2 = model2.predict(X_val)
print("Done")

print("Fitting LinearSVC..")
model3.fit(X_train,y_train)
pred3 = model3.predict(X_test)
val3 = model3.predict(X_val)
print("Done")

print("Fitting AdaBoostClassifier..")
model4.fit(X_train,y_train)
pred4 = model4.predict(X_test)
val4 = model4.predict(X_val)
print("Done")

#generate train data for stacking 
stacked_train = np.column_stack((pred1, pred2, pred3, pred4))
stacked_val = np.column_stack((val1, val2, val3, val4))

#train stacked model
print("Fitting Stacked Model..")
meta_model.fit(stacked_train,y_test)
y_pred = meta_model.predict(stacked_val)
print("Done")

#evaluation metrics for stacked model
print("Classification Report:\n{}".format(classification_report(y_val,y_pred)))

#accuracy and confusion matrix
print("Accuracy: {:.3f}".format(accuracy_score(y_val, y_pred))) 
print("\nConfusion matrix:\n{}".format(confusion_matrix(y_val, y_pred)))

#micro,macro and weighted scores
print("\nMicro average f1 score: {:.3f}".format (f1_score(y_val, y_pred, average="micro")))
print("Macro average f1 score: {:.3f}".format (f1_score(y_val, y_pred, average="macro")))
print("Weighted average f1 score: {:.3f}".format (f1_score(y_val, y_pred, average="weighted")))
# Out:
# Fiting Logistic Regression..
# Done
# Fiting GradientBoostedClassifier..
# Done
# Fitting LinearSVC..
# Done
# Fitting AdaBoostClassifier..
# Done
# Fitting Stacked Model..
# Done
# Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.63      0.67      0.65       323
#          2.0       0.49      0.72      0.59       425
#          3.0       0.16      0.04      0.07       136
#          4.0       0.00      0.00      0.00        36
#          5.0       0.17      0.02      0.04        47
#          6.0       0.31      0.12      0.18        40
#          7.0       1.00      0.15      0.26        20
#
#    micro avg       0.52      0.52      0.52      1027
#    macro avg       0.40      0.25      0.26      1027
# weighted avg       0.46      0.52      0.47      1027
#
# Accuracy: 0.525
#
# Confusion matrix:
# [[217 102   2   0   1   1   0]
#  [111 307   7   0   0   0   0]
#  [  9 120   6   0   0   1   0]
#  [  0  31   4   0   1   0   0]
#  [  4  32   9   0   1   1   0]
#  [  0  27   7   0   1   5   0]
#  [  1   4   2   0   2   8   3]]
#
# Micro average f1 score: 0.525
# Macro average f1 score: 0.255
# Weighted average f1 score: 0.471
